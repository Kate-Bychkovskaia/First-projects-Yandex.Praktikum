# %% [markdown]
# ## Test case №1
#
# Data was extracted from GCP. The dataset contains 4 million rows, but we were only able to extract them in small portions, about 40,000 rows in CSV format. In total, we ended up with 110 files. The files are named as follows:
#
# data_000000000001.csv
# data_000000000002.csv
#
# Please suggest a method for uploading all these 110 files using Jupyter Notebook (or another) and merging them into a single dataset for further processing.
#
# **This case will be solved in several steps:**
# - **1. Creating dataset for testing. Ending up into several files**
# - **2. Merging files into a single dataset**

# %%
import pandas as pd
import os

# %%
try:
    df=pd.read_csv('/test_data.csv')
except: 
    df=pd.read_csv('/Users/ekaterina/Documents/thumos_test/dataset/test_data.csv')
    
df.tail(5)
# Out:
#     Campaign_id             Geo    Buyer  Impressions  Clicks  Installs  \
# 82           83             cis  buyer_2        15729     451       180
# 83           84  western europe  buyer_5        16404     210        69
# 84           85  western europe  buyer_4        27422     358       113
# 85           86             cis  buyer_4         8334     154        58
# 86           87   north america  buyer_2        16622     547       258
#
#     Registrations      Spend Revenue_ad1d Revenue_in_app1d  Payers1d  \
# 82             26  20,610001     2,283065                0         0
# 83             24  20,549999     2,342654                0         0
# 84             71      20,43     8,895793                0         0
# 85             27      20,43      2,12165             1,49         1
# 86            142      20,41    10,137634                0         0
#
#    Revenue_ad7d Revenue_in_app7d  Payers7d Revenue_ad30d Revenue_in_app30d  \
# ...

# %%
print("Length of the initial dataset:", len(df))
# Out:
# Length of the initial dataset: 87

# %% [markdown]
# Note for the reviewer. Yes, there are only 87 files, not 110. The idea was to show how it will be done, so I decided to take the real dataset from my previous analysis.

# %%
# new catalogue for splited files
output_directory = '/Users/ekaterina/Documents/thumos_test'
os.makedirs(output_directory, exist_ok=True)

# %%
# Split DataFrame on rows and save each row in a new csv file
for index, row in df.iterrows():
    #file's name formatting 
    output_file_path = os.path.join(output_directory, f'data_{index + 1:012d}.csv')
    
# create DataFrame with 1 row and save as new csv
    pd.DataFrame(row).T.to_csv(output_file_path, index=False)

# %% [markdown]
# ### 2. Merging files into a single dataset

# %%
# directory path where CSV files will be stored
directory_path = '/Users/ekaterina/Documents/thumos_test'

# Initialize an empty DataFrame to store the merged data
merged_data = []



# Loop through all files in the directory
for filename in os.listdir(directory_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(directory_path, filename)
        # Read each CSV file and append it to the merged_data DataFrame
        df = pd.read_csv(file_path)
        merged_data.append(df)
        

#Concatenate all DataFrames in the list into a single DataFrame
merged_data = pd.concat(merged_data, ignore_index=True)

#Display the first few rows of the merged dataset
merged_data.head()
# Out:
#    Campaign_id              Geo    Buyer  Impressions  Clicks  Installs  \
# 0           48              cis  buyer_5        76263    2103       743
# 1           60  tropical africa  buyer_1        90894    2735       778
# 2           74   western europe  buyer_4        12042     257        93
# 3           75    north america  buyer_1         3927     144        48
# 4           61   western europe  buyer_2        13002     315       123
#
#    Registrations      Spend Revenue_ad1d Revenue_in_app1d  Payers1d  \
# 0            166  61,759998    12,459399              3,1         1
# 1            485      41,51     5,473794                0         0
# 2             40      23,32     5,806555                0         0
# 3             21      23,32    16,291981                0         0
# 4             86  40,200001    19,178195                0         0
#
#   Revenue_ad7d Revenue_in_app7d  Payers7d Revenue_ad30d Revenue_in_app30d  \
# ...

# %%
#check the length of the final DataFrame
print("Length of the final dataset:", len(merged_data))
# Out:
# Length of the final dataset: 87
